# %% [markdown]
# # Imports

# %%
from pathlib import Path
import os
import sys
sys.path.append(str(Path(os.getcwd()).parent / 'middleware/middleware'))

# %%
import pandas as pd
from glob import glob
from functools import reduce
import random
import re
from src.pipelines.alpha import Alpha
from src.helpers import correct_encoding, read_jsonl, write_jsonl
from IPython.display import clear_output

# %% [markdown]
# # Loading export

# %%
df = pd.read_csv('data/exports/export_CR_PETCT-01012016_an.csv', sep='\t', encoding='utf-8')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41184 entries, 0 to 41183
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NUMERO_EXAMEN   41184 non-null  object
#  1   TYPE_EXAMEN     41184 non-null  object
#  2   LIBELLE_EXAMEN  41184 non-null  object
#  3   NUM_SALLE       41184 non-null  object
#  4   DATE_EXAMEN     41184 non-null  object
#  5   HEURE_EXAMEN    41184 non-null  object
#  6   COMPTE_RENDU    41184 non-null  object
#  7   year            41184 non-null  int64
#  8   month           41184 non-null  int64
#  9   cr_an           41184 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 3.1+ MB
#   NUMERO_EXAMEN TYPE_EXAMEN    LIBELLE_EXAMEN NUM_SALLE DATE_EXAMEN  \
# 0  A10836454533          MN  TEP CORPS ENTIER    MBPET1    04/01/16
# 1  A10844655173          MN  TEP CORPS ENTIER    MBPET1    04/01/16
# 2  A10887608918          MN  TEP CORPS ENTIER    MBPET1    04/01/16
# 3  A10890051978          MN  TEP CORPS ENTIER    MBPET1    04/01/16
# 4  A10883861577          MN  TEP CORPS ENTIER    MBPET1    04/01/16
#
#   HEURE_EXAMEN                                       COMPTE_RENDU  year  \
# 0        08:01  Installation répertoriée sous le n° M540008 Au...    16
# 1        14:16  Installation répertoriée sous le n° M540008 Au...    16
# 2        14:52  Installation répertoriée sous le n° M540008 Au...    16
# 3        14:44  Installation répertoriée sous le n° M540008 Au...    16
# 4        11:11  Installation répertoriée sous le n° M540008 Au...    16
#
#    month                                              cr_an
# 0      1  Installation répertoriée sous le n° M540008 Au...
# 1      1  Installation répertoriée sous le n° M540008 Au...
# 2      1  Installation répertoriée sous le n° M540008 Au...
# 3      1  Installation répertoriée sous le n° M540008 Au...
# 4      1  Installation répertoriée sous le n° M540008 Au...

# %% [markdown]
# # Loading of existing samples

# %%
existing_samples = reduce(lambda a, b: a+b, [read_jsonl(path) for path in glob('data/suv/dones/*.jsonl')])
existing_samples = [es['text'].strip() for es in existing_samples]
existing_samples[:5]
# Out:
# ["Hypermétabolisme intense de la région vulvaire très suspect de récidive locale (SUVmax à 9,5 pour une référence hépatique de l'ordre de 3)",
#  "Image nodulaire de la loge thymique 15x7x12 mm, aux contours réguliers, discrètement fixante (SUVmax de 2.3)  non retrouvée rétrospectivement sur l'examen  TEP précédent, priori le plus vraisemblablement ganglionnaire",
#  'Adénopathies hypermétaboliques lombo-aortiques, iliaques primitives, internes et externes bilatérales avec une cible métabolique en iliaque externe droite (SUVmax à 4.5) sur une lésion de 26x10.5mm dans le plan axial.',
#  "Epaississement circonférentiel pleural droit et épanchement hypermétabolique (SUVmax à 7,3 pour une référence hépatique à 2,8), de façon diffuse mais hétérogène avec présence de plusieurs nodules hypermétaboliques disséminés sur l'hémichamp pulmonaire droit.\r\nAtélectasie lobaire inférieure droite non hypermétabolique.\r\nAdénopathies hypermétaboliques pré-trachéale droite, sous-carinaire et hilaire droite, la plus volumineuse pré-trachéale de 15 x 20 mm, la plus hypermétabolique sous-carinaire (SUVmax à 4).",
#  'À noter que les deux examens ont été réalisés sur deux TEP différentes (numérique vs analogique), rendant difficile la comparaison des SUVmax']

# %% [markdown]
# # Loading model

# %%
nlp = Alpha('../middleware/middleware/models').nlp

# %% [markdown]
# # Making sample

# %%
seed = 0
N = 1000
MATCHER = re.compile(r'suv', re.I)
SECTION = (3, 'obs')
RESULT_PATH = 'data/suv/to_annotated/suv_2000_3000.jsonl'

new_samples = []
random_ids = list(range(len(df)))
random.seed(seed)
random.shuffle(random_ids)

while len(new_samples) < 1000 and len(random_ids) != 0:
    cr = df.loc[random_ids.pop(), 'cr_an']
    if isinstance(cr, float):
        continue
    try:
        doc = nlp(cr)
    except:
        pass
    
    if len(doc._.sections) < SECTION[0] or doc._.sections[SECTION[0]].label_ != SECTION[1]:
        continue
        
    for sent in list(doc._.sections[3].as_doc().sents):
        txt = sent.text
        if MATCHER.search(txt) != None and txt.strip() not in existing_samples and txt.strip() not in new_samples:
            new_samples.append(txt)
            
    clear_output(wait=True)
    print(f'{len(new_samples)}/{N}, {len(new_samples)/N:.2f}')
    
write_jsonl(RESULT_PATH, [{'text':txt} for txt in new_samples])
# Out:
# 1000/1000, 1.00

# %% [markdown]
# # Gathering samples

# %%
samples = reduce(lambda a, b: a+b, [read_jsonl(path) for path in glob('data/suv/dones/*.jsonl')])
len(samples)
# Out:
# 2001

# %%
write_jsonl('data/suv/suv_loc.jsonl', samples)

# %% [markdown]
# # Explore samples

# %%
[sample for sample in read_jsonl('data/suv/dones/suv_loc_0.jsonl') if sample['annotation_approver'] == None]
# Out:
# [{'id': 4181,
#   'text': 'SUVmax à 3,2 pour une référence hépatique à 3,2.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[9, 12, 'SUV_MAX'], [44, 47, 'SUV_REF']]},
#  {'id': 4183,
#   'text': "Quelques lésions ganglionnaires cervicales infra et juxta-centimétriques bilatérales peu voire non hypermétaboliques avec la lésion la plus volumineuse en prétragien droit de 16x8mm dans le plan axial (SUVmax de l'ordre de 2.5 pour une référence médiastinale à 3 et hépatique à 3.5).\r\nUn foyer ganglionnaire hypermétabolique axillaire droit profond (SUVmax à 3) de 10x7mm et infra centimétrique sus-claviculaire droit.",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[32, 48, 'OBJ_LOC'],
#    [52, 84, 'OBJ_LOC'],
#    [155, 171, 'OBJ_LOC'],
#    [223, 226, 'SUV_MAX'],
#    [278, 281, 'SUV_REF'],
#    [325, 349, 'OBJ_LOC'],
#    [359, 360, 'SUV_MAX'],
#    [395, 417, 'OBJ_LOC'],
#    [261, 262, 'SUV_REF']]},
#  {'id': 4186,
#   'text': 'Adénopathies hypermétaboliques lombo-aortiques, iliaques primitives, internes et externes bilatérales avec une cible métabolique en iliaque externe droite (SUVmax à 4.5) sur une lésion de 26x10.5mm dans le plan axial.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[31, 46, 'OBJ_LOC'],
#    [48, 67, 'OBJ_LOC'],
#    [69, 101, 'OBJ_LOC'],
#    [132, 154, 'OBJ_LOC'],
#    [165, 168, 'SUV_MAX']]},
#  {'id': 4204,
#   'text': "Epaississement circonférentiel pleural droit et épanchement hypermétabolique (SUVmax à 7,3 pour une référence hépatique à 2,8), de façon diffuse mais hétérogène avec présence de plusieurs nodules hypermétaboliques disséminés sur l'hémichamp pulmonaire droit.\r\nAtélectasie lobaire inférieure droite non hypermétabolique.\r\nAdénopathies hypermétaboliques pré-trachéale droite, sous-carinaire et hilaire droite, la plus volumineuse pré-trachéale de 15 x 20 mm, la plus hypermétabolique sous-carinaire (SUVmax à 4).",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[122, 125, 'SUV_REF'],
#    [392, 406, 'OBJ_LOC'],
#    [507, 508, 'SUV_MAX'],
#    [230, 257, 'OBJ_LOC'],
#    [352, 372, 'OBJ_LOC'],
#    [482, 496, 'OBJ_LOC'],
#    [31, 44, 'OBJ_LOC'],
#    [87, 90, 'SUV_MAX'],
#    [374, 388, 'OBJ_LOC'],
#    [272, 297, 'OBJ_LOC']]},
#  {'id': 4207,
#   'text': 'À noter que les deux examens ont été réalisés sur deux TEP différentes (numérique vs analogique), rendant difficile la comparaison des SUVmax',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': []},
#  {'id': 4214,
#   'text': "Hypermétabolisme d'un ganglion jugulo-carotidien infracentimétrique du groupe II droit (SUV max = 4,1 pour une référence hépatique max = 4,1 et des valeurs respectives précédentes à 3,6 et 4,3)",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[98, 101, 'SUV_MAX'],
#    [137, 140, 'SUV_REF'],
#    [182, 185, 'SUV_MAX'],
#    [189, 192, 'SUV_REF'],
#    [31, 86, 'OBJ_LOC']]},
#  {'id': 4246,
#   'text': 'SUV max 2,3 \x96',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[8, 11, 'SUV_MAX']]},
#  {'id': 4247,
#   'text': 'SUV max 3,1',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[8, 11, 'SUV_MAX']]},
#  {'id': 4248,
#   'text': 'SUV max 2,5 et 2,2',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[8, 11, 'SUV_MAX'], [15, 18, 'SUV_MAX']]},
#  {'id': 4249,
#   'text': 'SUV max 2,5.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[8, 11, 'SUV_MAX']]},
#  {'id': 4252,
#   'text': ", persistance de quelques images résiduelles de taille bien moindre qu'auparavant avec un conglomérat que l'on peut grossièrement estimer à 3.5x2.5 cm contre 6x4 cm sur l'examen précédent avec notamment une adénopathie passée de 29x20 mm à 17x10 mm (la valeur de SUVmax de ce conglomérat est de 1.7 pour 2.4 au niveau du foie et 1.5 au niveau du médiastin (Deauville 3).",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[295, 307, 'SUV_MAX'], [329, 332, 'SUV_REF']]},
#  {'id': 4253,
#   'text': 'Adénopathies sus-claviculaires gauches hypermétaboliques (SUV max = 18,7 pour une référence hépatique max = 2,4).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[13, 38, 'OBJ_LOC'], [68, 72, 'SUV_MAX'], [108, 111, 'SUV_REF']]},
#  {'id': 4254,
#   'text': '(SUVmax = 20,9).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[10, 14, 'SUV_MAX']]},
#  {'id': 4263,
#   'text': 'SUVmax hépatique : 3,3 versus 2,9',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': []},
#  {'id': 4278,
#   'text': 'SUV max hépatique : 4',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[20, 21, 'SUV_MAX']]},
#  {'id': 4331,
#   'text': 'II droit de 30 * 27 mm ainsi que  axillaires bilatérales, la plus volumineuse de 35 * 54  mm axillaire gauche (SUVmax à 2,4)',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[34, 56, 'OBJ_LOC'],
#    [93, 109, 'OBJ_LOC'],
#    [120, 123, 'SUV_MAX']]},
#  {'id': 4332,
#   'text': 'la plus volumineuse sous-carinaire (SUVmax à 2,7)',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[45, 48, 'SUV_MAX'], [20, 34, 'OBJ_LOC']]},
#  {'id': 4375,
#   'text': "Polyadénopathie sus-claviculaire bilatérale et médiastinale supérieure non hypermétaboliques à l'exception d'un foyer ganglionnaire sus-claviculaire gauche en regard d'une adénopathie centimétrique avec un SUVmax à 4,5",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[16, 43, 'OBJ_LOC'],
#    [47, 70, 'OBJ_LOC'],
#    [132, 155, 'OBJ_LOC'],
#    [215, 218, 'SUV_MAX']]},
#  {'id': 4354,
#   'text': "présence en dessous d'une adénopathie hyperfixante (SUVmax de 11) située juste en dessous, superficielle, au contact de la branche montante de la mandibule, mesurant environ 3,5x2,5 cm en axial et 2 cm en frontal, et plus bas d'une autre adénopathie hyperfixante (SUVmax de 9), en sous-mandibulaire, mesurant environ 2x1.5 cm mm en axial ;",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[62, 64, 'SUV_MAX'],
#    [123, 155, 'OBJ_LOC'],
#    [274, 275, 'SUV_MAX'],
#    [281, 298, 'OBJ_LOC']]},
#  {'id': 4380,
#   'text': 'Masse ganglio-tumorale médiastinale antérieure droite intensément hypermétabolique de 66 x 30 mm en axial  avec SUVmax à 12,4',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[22, 53, 'OBJ_LOC'], [121, 125, 'SUV_MAX']]},
#  {'id': 4393,
#   'text': "Hyperfixation franche avec un SUVmax de 4.5 contre 2.5 au niveau du foie de cette lésion nodulaire lobaire moyenne d'environ 10mm de diamètre qui s'accompagne à son contact juste en avant d'une seconde lésion quant à elle non fixante d'environ 9mm de diamètre ;",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[40, 54, 'SUV_MAX'], [99, 106, 'OBJ_LOC']]},
#  {'id': 4405,
#   'text': 'Splénomégalie de métabolisme homogène (flèche mesurée à 21 cm) avec un SUVmax à 1,8 pour une référence hépatique à 2.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[39, 45, 'OBJ_LOC'], [115, 116, 'SUV_REF'], [80, 83, 'SUV_MAX']]},
#  {'id': 4406,
#   'text': 'Foyer hypermétabolique ganglionnaire sus-claviculaire droit (SUVmax à 3,7).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[37, 59, 'OBJ_LOC'], [70, 73, 'SUV_MAX']]},
#  {'id': 4420,
#   'text': 'dans le plan axial (SUVmax à 10.2 pour une référence hépatique à 3) avec épaississement diffus hypermétabolique du revêtement cutané en regard.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[29, 33, 'SUV_MAX'], [65, 66, 'SUV_REF'], [115, 132, 'OBJ_LOC']]},
#  {'id': 4430,
#   'text': 'Ganglion inguinal droit de 9 x 8 mm modérément hypermétabolique (SUVmax à 3.5).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[9, 23, 'OBJ_LOC'], [74, 77, 'SUV_MAX']]},
#  {'id': 4435,
#   'text': 'avec en externe gauche une lésion de 16 x 12 mm avec un SUVmax à 5,5.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[8, 22, 'OBJ_LOC'], [65, 68, 'SUV_MAX']]},
#  {'id': 4441,
#   'text': 'Quelques ganglions modérément hypermétaboliques para-trachéal inférieur droit et hilaires droits (SUVmax à 3,6 m.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[48, 77, 'OBJ_LOC'], [81, 96, 'OBJ_LOC'], [107, 110, 'SUV_MAX']]},
#  {'id': 4461,
#   'text': 'Discrète progression morpho-métabolique du nodule tissulaire situé au bord latéral du muscle soléaire gauche (SUVmax = 1,6 pour une valeur précédente = 1).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[70, 108, 'OBJ_LOC'],
#    [119, 122, 'SUV_MAX'],
#    [152, 153, 'SUV_MAX']]},
#  {'id': 4469,
#   'text': 'SUVmax hépatique : 4,3',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[19, 22, 'OBJ_LOC']]},
#  {'id': 4490,
#   'text': "Intense hypermétabolisme de la volumineuse lésion \x9csophagienne connue, débutant à hauteur de la carène et s'étendant sur environ 78 mm de haut (SUVmax à 8,1 pour une référence hépatique max à 1,7)",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[51, 62, 'OBJ_LOC'],
#    [153, 156, 'SUV_MAX'],
#    [192, 195, 'SUV_REF'],
#    [82, 102, 'OBJ_LOC']]},
#  {'id': 4520,
#   'text': 'SUVmax hépatique : 3',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[19, 20, 'SUV_MAX']]},
#  {'id': 4518,
#   'text': '-aortiques et inter-aortico-caves (SUV max à 2.4).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[45, 48, 'SUV_MAX']]},
#  {'id': 4526,
#   'text': "Discrète augmentation du métabolisme de la lésion de l'arc postérieur de la 5e côte gauche (SUVmax 3,5 versus 2,3), à surveiller.",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[53, 90, 'OBJ_LOC'], [99, 113, 'SUV_MAX']]},
#  {'id': 4558,
#   'text': 'SUVmax hépatique : 3,9',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[19, 22, 'OBJ_LOC']]},
#  {'id': 4564,
#   'text': 'SUVmax 4,5 / référence hépatique à 3,1',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[7, 10, 'OBJ_LOC'], [35, 38, 'OBJ_LOC']]},
#  {'id': 4582,
#   'text': "siège d'une fixation intense (SUVmax 18) ;",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[37, 39, 'OBJ_LOC']]},
#  {'id': 4586,
#   'text': "G hyperfixante de façon intesne (SUVMax 10) d'environ 5x5x3.5 cm de diamètre, infiltrant l'ensemble du hile gauche et s'étendant au médiastin infiltrant la région inter-aorto-pulmonaire (SUVmax 9), se prolongeant en control latéral au niveau de la loge de Baréty et se prolongeant en avant au bord gauche de l'aorte ascendante avec en outre deux ganglions hyperfixants en avant de l'aorte ascendante",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[40, 42, 'SUV_MAX'],
#    [103, 114, 'OBJ_LOC'],
#    [132, 141, 'OBJ_LOC'],
#    [156, 185, 'OBJ_LOC'],
#    [194, 195, 'SUV_MAX'],
#    [248, 262, 'OBJ_LOC'],
#    [293, 315, 'OBJ_LOC'],
#    [381, 399, 'OBJ_LOC']]},
#  {'id': 4591,
#   'text': "Présence d'une masse au niveau du hile splénique, mesurant environ 3.5x3 cm avec une valeur de SUVmax de l'ordre de 6",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[34, 48, 'OBJ_LOC'], [116, 117, 'SUV_MAX']]},
#  {'id': 4603,
#   'text': 'Persistance de 5 lésions axillaires droites avec de haut en bas : une lésion apparue de 13x10 mm avec une SUVmax de 5, une lésion passée de 6 à 9 mm non fixante, une lésion stable en taille de 9 mm avec une SUVmax passée de 5 à 7, une lésion passée de 13 à 16 mm avec une SUVmax passée de 7 à 8 et enfin une lésion stable de 20x20 mm avec une SUVmax stable de 12.',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[24, 43, 'OBJ_LOC'],
#    [116, 117, 'SUV_MAX'],
#    [224, 229, 'SUV_MAX'],
#    [289, 294, 'SUV_MAX'],
#    [360, 362, 'SUV_MAX']]},
#  {'id': 4623,
#   'text': '(SUVmax à 3.3).',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': []},
#  {'id': 4643,
#   'text': "Hypermétabolisme d'un nodule spiculé juxta scissural postérieur du lobe supérieur droit, mesuré à 17x8mm (SUVmax à 1.9).",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[37, 87, 'OBJ_LOC'], [115, 118, 'SUV_MAX']]},
#  {'id': 4644,
#   'text': 'Deux ganglions hypermétaboliques hilaire droit (SUVmax à 4 pour une référence hépatique à 2.6) et para trachéal inférieur droit (SUVmax à 3.2),',
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[33, 46, 'OBJ_LOC'],
#    [57, 58, 'SUV_MAX'],
#    [90, 93, 'SUV_REF'],
#    [138, 141, 'SUV_MAX'],
#    [98, 127, 'OBJ_LOC']]},
#  {'id': 4654,
#   'text': "Persistance et stabilité d'un hypermétabolisme gastrique diffus d'intensité modérée, complètement aspécifique (SUVmax à 4.6 versus 3.9 pour des références hépatiques similaires de l'ordre de 3)",
#   'meta': {},
#   'annotation_approver': None,
#   'labels': [[47, 56, 'OBJ_LOC'],
#    [120, 134, 'SUV_MAX'],
#    [191, 192, 'SUV_REF']]}]
